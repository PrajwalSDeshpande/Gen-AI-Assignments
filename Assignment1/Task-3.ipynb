# %%
price_dict={"T-shirt":125,'Pant':100,"sun-screen":400,'soap':45.5,'pen':10.75,'chalk':5}
price_dict['bread']=40
print(price_dict)
price_dict['Pant']=145
print(price_dict)
del price_dict["chalk"]
print(price_dict)

addn=sum(price_dict.values())
avg=addn/len(price_dict)
print(avg)
# Out:
# {'T-shirt': 125, 'Pant': 100, 'sun-screen': 400, 'soap': 45.5, 'pen': 10.75, 'chalk': 5, 'bread': 40}
# {'T-shirt': 125, 'Pant': 145, 'sun-screen': 400, 'soap': 45.5, 'pen': 10.75, 'chalk': 5, 'bread': 40}
# {'T-shirt': 125, 'Pant': 145, 'sun-screen': 400, 'soap': 45.5, 'pen': 10.75, 'bread': 40}
# 127.70833333333333
