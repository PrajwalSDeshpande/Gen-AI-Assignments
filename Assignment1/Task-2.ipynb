# %%
categories_Set={'Clothing','stationary','body-care'}
categories_Set.add("Clothing")
print(categories_Set)
if 'Clothing' in categories_Set:
    print("category exists")
else:
    print("Category does not exist")
# Out:
# {'Clothing', 'body-care', 'stationary'}
# category exists
