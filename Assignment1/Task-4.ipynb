# %%
products=['tshirts','pants','sun-screen','soap','notebook']
price_dict={"tshirts":125,'pants':100,"sun-screen":400,'soap':45.5,'notebook':20}
catalog=[('tshirts',125,'clothing'),('pants',100,'clothing'),('sun-screen',400,'bodycare'),('soap',45.5,'bodycare'),('notebook',20,'stationary')]
categories_to_products={'clothing':['tshirts','pants'],'bodycare':['sun-screen','soap'],'stationary':['notebook']}
print(max(categories_to_products,key=lambda x:len(categories_to_products[x])))
# Out:
# clothing
